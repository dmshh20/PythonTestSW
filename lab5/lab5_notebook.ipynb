# %% [markdown]
# # Lab 5 — ООП (коротка демонстрація)
#
# У цьому ноутбуці швидко продемонстровано роботу класу MyName. Запустіть кодові ячейки.

# %%
# Імпортуємо клас з файлу (переконайтесь, що lab5_examples.py знаходиться в тій же теці)
from lab5_examples import MyName

# Створюємо кілька об'єктів
users = [MyName('olena'), MyName(None), MyName('Taras')]
for u in users:
    print(u.full_name)
    print('length:', u.name_length())
    print('email custom domain:', u.create_email('example.com'))
    print('-'*20)

# %% [markdown]
# Очікуваний результат: рядки з `full_name`, довжина імені та email з модифікованим доменом.
