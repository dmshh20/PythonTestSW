# %% [markdown]
# # Демонстрація — Lab5 Парадигми ООП
# Автоматична симуляція бою двох випадково створених зброї.

# %%
from paradigms_game import create_random_weapon, simulate_auto_match
a = create_random_weapon('A')
b = create_random_weapon('B')
print('A:', type(a), a.name, 'HP=', a.health)
print('B:', type(b), b.name, 'HP=', b.health)
result = simulate_auto_match(a, b)
print('Result:', result)
